# %% [markdown]
# ### [Kaggle URL: world-happiness](https://www.kaggle.com/unsdsn/world-happiness)

# %%
import pandas as pd

data_2015=pd.read_csv('./2015.csv')
data_2016=pd.read_csv('./2016.csv')
data_2017=pd.read_csv('./2017.csv')
data_2018=pd.read_csv('./2018.csv')
data_2019=pd.read_csv('./2019.csv')

# %% [markdown]
# ## 2015년도 행복과 행복측정지수 간의 상관관계 분석

# %%
df_2015=pd.DataFrame(data_2015[['Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)',
                                'Trust (Government Corruption)','Generosity','Dystopia Residual']])
corr_2015=df_2015.corr()
corr_2015
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780966
# Economy (GDP per Capita)              0.780966                  1.000000
# Family                                0.740605                  0.645299
# Health (Life Expectancy)              0.724200                  0.816478
# Trust (Government Corruption)         0.395199                  0.307885
# Generosity                            0.180319                 -0.010465
# Dystopia Residual                     0.530474                  0.040059
#
#                                  Family  Health (Life Expectancy)  \
# Happiness Score                0.740605                  0.724200
# Economy (GDP per Capita)       0.645299                  0.816478
# Family                         1.000000                  0.531104
# Health (Life Expectancy)       0.531104                  1.000000
# ...

# %% [markdown]
# ## 2016년도 행복과 행복측정지수 간의 상관관계 분석

# %%
df_2016=pd.DataFrame(data_2016[['Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)',
                                'Trust (Government Corruption)','Generosity','Dystopia Residual']])
corr_2016=df_2016.corr()
corr_2016
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.790322
# Economy (GDP per Capita)              0.790322                  1.000000
# Family                                0.739252                  0.669540
# Health (Life Expectancy)              0.765384                  0.837067
# Trust (Government Corruption)         0.402032                  0.294185
# Generosity                            0.156848                 -0.025531
# Dystopia Residual                     0.543738                  0.068624
#
#                                  Family  Health (Life Expectancy)  \
# Happiness Score                0.739252                  0.765384
# Economy (GDP per Capita)       0.669540                  0.837067
# Family                         1.000000                  0.588377
# Health (Life Expectancy)       0.588377                  1.000000
# ...

# %% [markdown]
# ## 2017년도 행복과 행복측정지수 간의 상관관계 분석

# %%
df_2017=pd.DataFrame(data_2017[['Happiness.Score',"Economy..GDP.per.Capita.",'Family',"Health..Life.Expectancy.","Freedom",
                                'Generosity', "Trust..Government.Corruption.","Dystopia.Residual"]])
corr_2017=df_2017.corr()
corr_2017
# Out:
#                                Happiness.Score  Economy..GDP.per.Capita.  \
# Happiness.Score                       1.000000                  0.812469
# Economy..GDP.per.Capita.              0.812469                  1.000000
# Family                                0.752737                  0.688296
# Health..Life.Expectancy.              0.781951                  0.843077
# Freedom                               0.570137                  0.369873
# Generosity                            0.155256                 -0.019011
# Trust..Government.Corruption.         0.429080                  0.350944
# Dystopia.Residual                     0.475355                  0.024226
#
#                                  Family  Health..Life.Expectancy.   Freedom  \
# Happiness.Score                0.752737                  0.781951  0.570137
# Economy..GDP.per.Capita.       0.688296                  0.843077  0.369873
# Family                         1.000000                  0.612080  0.424966
# ...

# %% [markdown]
# ## 2018년도 행복과 행복측정지수 간의 상관관계 분석

# %%
df_2018=pd.DataFrame(data_2018[['Score',"GDP per capita",'Social support',"Healthy life expectancy",
                                "Freedom to make life choices", 'Generosity', "Perceptions of corruption"]])
corr_2018=df_2018.corr()
corr_2018
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.802124        0.745760
# GDP per capita                0.802124        1.000000        0.672080
# Social support                0.745760        0.672080        1.000000
# Healthy life expectancy       0.775814        0.844273        0.667288
# Freedom to make life choices  0.544280        0.332275        0.411087
# Generosity                    0.135825       -0.011241        0.018226
# Perceptions of corruption     0.405292        0.319582        0.218364
#
#                               Healthy life expectancy  \
# Score                                        0.775814
# GDP per capita                               0.844273
# Social support                               0.667288
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.355475
# Generosity                                   0.020751
# ...

# %% [markdown]
# * After 2018, the term 'Family' changed to 'Social support'. There are two points we can talk about at here.
#     1. 가족으로부터 얻는 행복이 개개인의 행복에 더이상 큰 영향을 미치지 않는다는 것을 의미
#     2. 그러면서 사람들은 가족보다는 개인 자체에 사회적으로 어떤 지원을 받을 수 있는가로부터 행복의 의미를 찾기 시작함

# %% [markdown]
# ## 2019년도 행복과 행복측정지수 간의 상관관계 분석

# %%
df_2019=pd.DataFrame(data_2019[['Score',"GDP per capita",'Social support',"Healthy life expectancy",
                                "Freedom to make life choices", 'Generosity', "Perceptions of corruption"]])
corr_2019=df_2019.corr()
corr_2019
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.793883        0.777058
# GDP per capita                0.793883        1.000000        0.754906
# Social support                0.777058        0.754906        1.000000
# Healthy life expectancy       0.779883        0.835462        0.719009
# Freedom to make life choices  0.566742        0.379079        0.447333
# Generosity                    0.075824       -0.079662       -0.048126
# Perceptions of corruption     0.385613        0.298920        0.181899
#
#                               Healthy life expectancy  \
# Score                                        0.779883
# GDP per capita                               0.835462
# Social support                               0.719009
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.390395
# Generosity                                  -0.029511
# ...
